# %%
# !git clone https://github.com/ultralytics/yolov5 
# %cd yolov5
# %pip install -qr requirements.txt  
import torch
from IPython.display import Image, clear_output  
clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu101 (Tesla T4)

# %%
# !python detect.py --weights yolov5s.pt --conf 0.5 --source /content/whitebrezza_Trim.mp4 --save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=True, source='/content/whitebrezza_Trim.mp4', update=False, view_img=False, weights=['yolov5s.pt'])
# YOLOv5 🚀 v5.0-112-g9f3a388 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 106MB/s]
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# video 1/1 (1/399) /content/whitebrezza_Trim.mp4: 384x640 1 car, Done. (0.046s)
# video 1/1 (2/399) /content/whitebrezza_Trim.mp4: 384x640 1 car, Done. (0.010s)
# video 1/1 (3/399) /content/whitebrezza_Trim.mp4: 384x640 1 car, Done. (0.010s)
# video 1/1 (4/399) /content/whitebrezza_Trim.mp4: 384x640 1 car, Done. (0.010s)
# ...

# %%
from google.colab import drive

# %%
drive.mount('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %%
cd /content/mydrive/MyDrive
# Out:
# /content/mydrive/MyDrive

# %%
mkdir ObjectTracking

# %%
cd /content/yolov5/
# Out:
# /content/yolov5

# %%
cp -a /content/yolov5/runs/detect/exp/labels/. /content/mydrive/MyDrive/ObjectTracking/
